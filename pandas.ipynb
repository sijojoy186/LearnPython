# %% [markdown]
# <a href="https://colab.research.google.com/github/sijojoy186/LearnPython/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
li = np.arange(1,4)

npArray = np.array(li)

sList = pd.Series(li)
sAry = pd.Series(npArray,['abc','mno','xyz']) + 2.5

print(sList)
print(sAry)
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64
# abc    3.5
# mno    4.5
# xyz    5.5
# dtype: float64

# %%
stud = ['Manu', 'Sonu', 'Tomy']

df1 = pd.DataFrame(stud,columns=['Student'])
df1
# Out:
#   Student
# 0    Manu
# 1    Sonu
# 2    Tomy

# %%
grade=['A','A+','B']
df2 = pd.DataFrame({'Name':stud, 'Grade':grade})
df2
# Out:
#    Name Grade
# 0  Manu     A
# 1  Sonu    A+
# 2  Tomy     B

# %%
df3 = pd.DataFrame(np.random.randn(5,2),columns=['A','B'])
df3
# Out:
#           A         B
# 0  2.202345  0.500342
# 1  1.233905 -0.669825
# 2  0.085185  1.188221
# 3  0.216185 -1.450677
# 4  1.302273  0.096419

# %%
day = ['day1', 'day2', 'day3', 'day4']
temperature = [31, 28, 30, 32] #temperature in degree Celsius
temp_data = pd.Series(temperature, index=day)
temp_data[2:]
# Out:
# day3    30
# day4    32
# dtype: int64

# %%
calorie_data = pd.DataFrame({'day': ['day1','day2','day3','day4','day5']
                           ,'calories': [450, 300, 345, 520, 600]
                           ,'duration_min': [30, 25, 29, 39, 48]
                           })
calorie_data[:2]
# Out:
#     day  calories  duration_min
# 0  day1       450            30
# 1  day2       300            25

# %%
calorie_data = pd.DataFrame({'day': ['day1','day2','day3','day4','day5']
                           ,'calories': [450, 300, 345, 520, 600]
                           ,'duration_min': [30, 25, 29, 39, 48]
                           })
calorie_data['calories']
# Out:
# 0    450
# 1    300
# 2    345
# 3    520
# 4    600
# Name: calories, dtype: int64

# %%
calorie_data = pd.DataFrame({'day': ['day1','day2','day3','day4','day5']
                           ,'calories': [450, 300, 345, 520, 600]
                           ,'duration_min': [30, 25, 29, 39, 48]
                           })
calorie_data[0:5:2]
# Out:
#     day  calories  duration_min
# 0  day1       450            30
# 2  day3       345            29
# 4  day5       600            48

# %%
calorie_data = pd.DataFrame({'day': ['day1','day2','day3','day4','day5']
                           ,'calories': [450, 300, 345, 520, 600]
                           ,'duration_min': [30, 25, 29, 39, 48]
                           })
calorie_data.loc[0]
# Out:
# day             day1
# calories         450
# duration_min      30
# Name: 0, dtype: object
